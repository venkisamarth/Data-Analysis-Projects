# %% [markdown]
# <a href="https://colab.research.google.com/github/venkisamarth/Data-Analysis-Projects/blob/main/Project_3_Netflix_Data_Analytics_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing the dataset

# %%
data=pd.read_csv("netflix_titles.csv")

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# **Droping the unwanted columns**

# %%
data.drop(['release_year'],axis=1,inplace=True)

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added rating   duration  \
# 0  September 25, 2021  PG-13     90 min
# 1  September 24, 2021  TV-MA  2 Seasons
# 2  September 24, 2021  TV-MA   1 Season
# ...

# %% [markdown]
# Getting the basic Inforamation about the dataset

# %% [markdown]
# **1. head()**

# %%
#To show the top-5 records of the data set
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added rating   duration  \
# 0  September 25, 2021  PG-13     90 min
# 1  September 24, 2021  TV-MA  2 Seasons
# 2  September 24, 2021  TV-MA   1 Season
# ...

# %% [markdown]
# 2. tail()

# %%
# To show the bottom-5 records  of the dataset
data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added rating   duration  \
# 8802  November 20, 2019      R    158 min
# 8803       July 1, 2019  TV-Y7  2 Seasons
# 8804   November 1, 2019      R     88 min
# 8805   January 11, 2020     PG     88 min
# ...

# %% [markdown]
# 3. shape

# %%
#To show the No. of Rows and Columns
data.shape
# Out:
# (8807, 11)

# %% [markdown]
# 5. columns

# %%
#To show each column name in the dataset
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# 6. Size

# %%
# To show the No. of the total values(elements) in the dataset
data.size
# Out:
# 96877

# %% [markdown]
# 7. dtypes

# %%
# Tp show the datatype of all columns
data.dtypes
# Out:
# show_id        object
# type           object
# title          object
# director       object
# cast           object
# country        object
# date_added     object
# rating         object
# duration       object
# listed_in      object
# description    object
# dtype: object

# %% [markdown]
# 8. info()

# %%
# To show the datatypes ,columns,data-types of each colums,memory at once
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   show_id      8807 non-null   object
#  1   type         8807 non-null   object
#  2   title        8807 non-null   object
#  3   director     6173 non-null   object
#  4   cast         7982 non-null   object
#  5   country      7976 non-null   object
#  6   date_added   8797 non-null   object
#  7   rating       8803 non-null   object
#  8   duration     8804 non-null   object
#  9   listed_in    8807 non-null   object
#  10  description  8807 non-null   object
# dtypes: object(11)
# memory usage: 757.0+ KB

# %% [markdown]
# Handling the duplicate records

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added rating   duration  \
# 0  September 25, 2021  PG-13     90 min
# 1  September 24, 2021  TV-MA  2 Seasons
# 2  September 24, 2021  TV-MA   1 Season
# ...

# %%
data.shape
# Out:
# (8807, 11)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, rating, duration, listed_in, description]
# Index: []

# %%
# To remove the duplicates records if present use below sysntax
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, rating, duration, listed_in, description]
# Index: []

# %%
data.shape
# Out:
# (8807, 11)

# %% [markdown]
# Handling the null value

# %%
#  To show the count of  number of Null values in each columns
data.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director       2634
# cast            825
# country         831
# date_added       10
# rating            4
# duration          3
# listed_in         0
# description       0
# dtype: int64

# %% [markdown]
# showing the null value with the heat map

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Visualising the Missing Values

# %%
import missingno as msno
msno.bar(data)
# Out:
# <Axes: >

# %%
msno.heatmap(data)
# Out:
# <Axes: >

# %%
msno.matrix(data)
# Out:
# <Axes: >

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# show_id        0
# type           0
# title          0
# director       0
# cast           0
# country        0
# date_added     0
# rating         0
# duration       0
# listed_in      0
# description    0
# dtype: int64

# %% [markdown]
# Outlier Identifiction

# %%
# Detection  Outlier, can be only applied to numeric values
sns.boxplot(x=data["year"])
plt.title("outlier Identification", fontsize=15)
plt.xlabel("Relese year",fontsize=10)
# Out:
# Text(0.5, 0, 'Relese year')

# %%
#Defining the Quartiles for removal of outliers
Q1 = data['year'].quantile(0.25)
Q3 = data['year'].quantile(0.75)
IQR = Q3 - Q1 #IQR stands for Inter quartile Range(IQR), i.e. difference between the 25th and 75th quantiles

lowOutlier = Q1 - 1.5 * IQR
highOutlier = Q3 + 1.5 * IQR
totalOutlier = ((data['year'] < lowOutlier) | (data['year'] > highOutlier)).sum()
print("Total Number of the Outliers in the year are {}".format(totalOutlier))
# Out:
# Total Number of the Outliers in the year are 41

# %%
data_filter = data[(data["year"] < highOutlier) & (data["year"] > lowOutlier)]

# %%
#validating the removal of outlier
totalOutlier = ((data_filter['year'] < lowOutlier) | (data_filter['year'] > highOutlier)).sum()
print("Total Number of Outliers in the year are {}".format(totalOutlier))
# Out:
# Total Number of Outliers in the year are 0

# %% [markdown]
# Data Visualisation

# %%
sns.set_theme(style="dark")

# %%
data_filter['type'].value_counts()
# Out:
# Movie      5098
# TV Show     143
# Name: type, dtype: int64

# %% [markdown]
# Content Type Distrubution Plot

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=data, x='type', palette='pastel')
plt.title('Count of Content Type Available', fontsize = 16)
plt.xlabel('Type of content', fontsize=12)
plt.show()

# %% [markdown]
# This bar plot shows the distribution of content types (movies and TV shows) on Netflix. The key insights from this plot are the proportion of movies to TV shows and how this proportion has evolved over time.
#
# Insight: Note the balance between movies and TV shows. A higher number of movies could suggest a focus on diverse, one-time content, while more TV shows might indicate a strategy to keep viewers engaged over longer periods

# %% [markdown]
# Rating Distribution Plot

# %%
data_rat = data_filter['rating'].value_counts().nlargest(5)
data_rat
# Out:
# TV-MA    1786
# TV-14    1203
# R         774
# PG-13     468
# TV-PG     420
# Name: rating, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.barplot(x=data_rat.index, y=data_rat, alpha=0.75, palette='pastel')
plt.title('Content available according to the top ratings', fontsize=20)
plt.ylabel('Content Available',fontsize=15)
plt.xlabel('Ratings', fontsize=15)
plt.xticks(fontsize=10)
plt.show()

# %% [markdown]
# Here, we visualize the distribution of content ratings. This plot is essential to understand the target audience for Netflix content and how it aligns with the platform's content strategy.
#
# Insight: Analyze the prevalence of different ratings (e.g., PG, R). A concentration of mature content might suggest targeting an older audience, while more family-friendly ratings indicate a broader target demographic.
#
# This information can be beneficial to the industry leader in deciding the distribution of content in respect of the rating of viewers according to the available content. Additionally, it is helpful for people to analyse the movies and tv shows content in respect of the rating they got from the authorized certification committee.

# %%
plt.figure(figsize=(8,5))
ax=sns.countplot(data=data_filter, x='rating', hue='type', palette='pastel')
plt.title(' Content Type available according to ratings', fontsize=15)
plt.xlabel('Rating', fontsize=14)
ax.legend(loc='center left', bbox_to_anchor=(0.600,0.90),
          ncol=3, fancybox=True, shadow=True)
plt.show()

# %% [markdown]
# Reginatl Content Availability

# %%
data_con=data_filter["country"].value_counts().nlargest(11)
data_con
# Out:
# United States     1780
# India              875
# United Kingdom     181
# Canada             104
# Spain               91
# Egypt               90
# Nigeria             87
# Japan               83
# Turkey              79
# Indonesia           76
# Philippines         74
# Name: country, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.barplot(x=data_con.index, y=data_con, alpha=0.75, palette='pastel')
plt.title('Content distribution according to the countries', fontsize=16, fontweight="bold")
plt.ylabel('Count of Content',fontsize=14)
plt.xlabel('Country', fontsize=14)
plt.xticks(fontsize=11)
plt.show()

# %%
sns.pairplot(data_filter, hue  = 'type')

# %%
# Displaying the correlation plot of the numerical values
# Select only numeric columns for correlation analysis
numeric_cols = data_filter.select_dtypes(include=[np.number])

# Alternatively, drop non-numeric columns
# numeric_cols = nfdf_filter.drop(['non_numeric_column1', 'non_numeric_column2'], axis=1)

# Now calculate the correlation
corr = numeric_cols.corr()

# Continue with your plotting
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='summer_r')
# Out:
# <Axes: >

# %% [markdown]
# **Release Year Analysis**

# %%
plt.figure(figsize=(12,8))
ax = sns.countplot(x="year", data=data_filter, palette="pastel",
                  order = data_filter["year"].value_counts().index)
plt.show
plt.title('Release year of content available', fontsize=16, fontweight="bold")
plt.xlabel('Release Year', fontsize=14)
# Out:
# Text(0.5, 0, 'Release Year')

# %% [markdown]
# Content Uplode Year Analysis

# %%
plt.figure(figsize=(12,8))
ax = sns.countplot(x="year", data=data_filter, palette="pastel",
                  order = data_filter["year"].value_counts().index)
plt.show
plt.title('Content uploaded over the years', fontsize=16, fontweight="bold")
plt.xlabel('Year uploaded at Netflix', fontsize=14)
# Out:
# Text(0.5, 0, 'Year uploaded at Netflix')

# %% [markdown]
# Q.1. For 'The Starling', what is the show id and who is the director of this show ?

# %%
data.head()
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %% [markdown]
# isin()

# %%
data[data["title"].isin(["The Starling"])] # To show the all record of a particular item in any clumns
# Out:
#   show_id   type         title        director  \
# 9     s10  Movie  The Starling  Theodore Melfi
#
#                                                 cast        country  \
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
#
#            date_added rating duration         listed_in  \
# 9  September 24, 2021  PG-13  104 min  Comedies, Dramas
#
#                                          description
# 9  A woman adjusting to life after a loss contend...

# %% [markdown]
# str.contains()

# %%
data[data["title"].str.contains("The Starling")]
# Out:
#   show_id   type         title        director  \
# 9     s10  Movie  The Starling  Theodore Melfi
#
#                                                 cast        country  \
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
#
#            date_added rating duration         listed_in  \
# 9  September 24, 2021  PG-13  104 min  Comedies, Dramas
#
#                                          description
# 9  A woman adjusting to life after a loss contend...

# %% [markdown]
# Q2. In which year highest number of the TV shows and Movies were released ? show with the Bar Graph

# %% [markdown]
# dtypes

# %%
data.dtypes
# Out:
# show_id        object
# type           object
# title          object
# director       object
# cast           object
# country        object
# date_added     object
# rating         object
# duration       object
# listed_in      object
# description    object
# dtype: object

# %% [markdown]
# to_datatime

# %%
data["Date_N"]=pd.to_datetime(data["date_added"])
# Out:
# <ipython-input-34-f1a631610639>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Date_N"]=pd.to_datetime(data["date_added"])

# %%
data
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
data.dtypes
# Out:
# show_id                object
# type                   object
# title                  object
# director               object
# cast                   object
# country                object
# date_added             object
# rating                 object
# duration               object
# listed_in              object
# description            object
# Date_N         datetime64[ns]
# dtype: object

# %% [markdown]
# dt.year.value_counts()

# %%
data["Date_N"].dt.year.value_counts()
# Out:
# 2019    1265
# 2020    1194
# 2018    1101
# 2021     755
# 2017     724
# 2016     202
# 2015      50
# 2014      14
# 2011      13
# 2013       7
# 2012       3
# 2009       2
# 2008       1
# 2010       1
# Name: Date_N, dtype: int64

# %% [markdown]
# wihth Bar Graph

# %%
data["Date_N"].dt.year.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# Q.3. How many Moves and  TV shows are in the dataset ? shows with Bar Graph.

# %% [markdown]
# groupby()

# %%
# show group all unique items of a columns and show thier count
data.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#   rating   duration                                         listed_in  \
# 7  TV-MA    125 min  Dramas, Independent Movies, International Movies
# 8  TV-14  9 Seasons                      British TV Shows, Reality TV
#
#                                          description     Date_N
# 7  On a photo shoot in Ghana, an American model s... 2021-09-24
# ...

# %%
#To group  all unique items of a  columns and show  thier counts
data.groupby("type").type.count()
# Out:
# type
# Movie      5185
# TV Show     147
# Name: type, dtype: int64

# %% [markdown]
# barplot

# %%
plt.bar(["Movie","TV Show"],data["type"].value_counts(),edgecolor = "k",width = 0.7)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# Q4. Show all the Movies that were released In year 2000.

# %% [markdown]
# creating the new column

# %%
data.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#   rating   duration                                         listed_in  \
# 7  TV-MA    125 min  Dramas, Independent Movies, International Movies
# 8  TV-14  9 Seasons                      British TV Shows, Reality TV
#
#                                          description     Date_N
# 7  On a photo shoot in Ghana, an American model s... 2021-09-24
# ...

# %%
data['year'] = data["Date_N"].dt.year
# Out:
# <ipython-input-43-79810762917c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['year'] = data["Date_N"].dt.year

# %%
data.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#   rating   duration                                         listed_in  \
# 7  TV-MA    125 min  Dramas, Independent Movies, International Movies
# 8  TV-14  9 Seasons                      British TV Shows, Reality TV
#
#                                          description     Date_N  year
# 7  On a photo shoot in Ghana, an American model s... 2021-09-24  2021
# ...

# %% [markdown]
# Filtering

# %%
data[(data['type']=='Movie') &(data["year"]==2000)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, rating, duration, listed_in, description, Date_N, year]
# Index: []

# %%
data[(data["type"]=="Movie")  & (data["year"]==2021)]
# Out:
#      show_id   type                                           title  \
# 7         s8  Movie                                         Sankofa
# 9        s10  Movie                                    The Starling
# 12       s13  Movie                                    Je Suis Karl
# 24       s25  Movie                                           Jeans
# 27       s28  Movie                                       Grown Ups
# ...      ...    ...                                             ...
# 8187   s8188  Movie                          The American President
# 8272   s8273  Movie                                    The Departed
# 8320   s8321  Movie                 The Girl with the Dragon Tattoo
# 8434   s8435  Movie  The Naked Gun: From the Files of Police Squad!
# 8461   s8462  Movie                               The Polar Express
#
#                  director                                               cast  \
# ...

# %% [markdown]
# Q5. Does Netflix  has more focus on TV shows than movies in recent years?

# %%
data["type"].value_counts()
# Out:
# Movie      5185
# TV Show     147
# Name: type, dtype: int64

# %%
data["type"].value_counts().plot(kind="bar",title="Type of shows netflix")
# Out:
# <Axes: title={'center': 'Type of shows netflix'}>

# %% [markdown]
# The insight from the above analysis is that we have more Moves than TV shows

# %% [markdown]
# Q6. Extract the top directors by number of moves made from the dataset

# %%
data.loc[data["type"]=="Movie","director"].value_counts().reset_index().head(10)
# Out:
#                     index  director
# 0  Raúl Campos, Jan Suter        18
# 1               Jay Karas        14
# 2            Marcus Raboy        14
# 3     Cathy Garcia-Molina        13
# 4             Jay Chapman        12
# 5         Youssef Chahine        12
# 6         Martin Scorsese        12
# 7        Steven Spielberg        11
# 8        Don Michael Paul        10
# 9            David Dhawan         9

# %% [markdown]
# Q3. How many uniqye countries  have produced movies?

# %%
data.loc[data["type"]=="Movie","country"].nunique()
# Out:
# 594

# %% [markdown]
# as per the current data 594 unique countries have produced moview but this data set a clebup,you can see why below

# %%
data["country"].value_counts()
# Out:
# United States                                   1846
# India                                            875
# United Kingdom                                   183
# Canada                                           107
# Spain                                             91
#                                                 ...
# Uruguay, Guatemala                                 1
# Romania, Bulgaria, Hungary                         1
# Philippines, United States                         1
# India, United Kingdom, Canada, United States       1
# United Arab Emirates, Jordan                       1
# Name: country, Length: 604, dtype: int64

# %% [markdown]
# **Q7. In what year were the least movies produced?**

# %%
data
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
data.loc[data["type"]=="Movie","year"].value_counts()
# Out:
# 2019    1236
# 2020    1151
# 2018    1085
# 2021     729
# 2017     702
# 2016     195
# 2015      47
# 2014      14
# 2011      13
# 2013       6
# 2012       3
# 2009       2
# 2008       1
# 2010       1
# Name: year, dtype: int64

# %% [markdown]
# From the above analysis we found out that minimum number of movies were produced in the year of 2010,2008,2009,2012,2013,2011and possibly more.

# %% [markdown]
# 8. What is the tv show woth maximum duration/seasons?

# %%
data.loc[data["type"]=="TV Show",["duration"]].value_counts().reset_index()
# Out:
#      duration    0
# 0    1 Season  106
# 1   2 Seasons   18
# 2   5 Seasons    6
# 3   4 Seasons    4
# 4   3 Seasons    3
# 5   6 Seasons    3
# 6   9 Seasons    3
# 7   8 Seasons    2
# 8  15 Seasons    1
# 9   7 Seasons    1

# %%
data.loc[data['duration'] == '15 Seasons', :]
# Out:
#      show_id     type         title       director  \
# 2423   s2424  TV Show  Supernatural  Phil Sgriccia
#
#                                                    cast  \
# 2423  Jared Padalecki, Jensen Ackles, Mark Sheppard,...
#
#                     country    date_added rating    duration  \
# 2423  United States, Canada  June 5, 2020  TV-14  15 Seasons
#
#                                               listed_in  \
# 2423  Classic & Cult TV, TV Action & Adventure, TV H...
#
#                                             description     Date_N  year
# 2423  Siblings Dean and Sam crisscross the country, ... 2020-06-05  2020

# %% [markdown]
# From the above anlysis we found out that Supernatural has the maximum seasons released among all the Tv show available on netflix

# %% [markdown]
# Q9. How many movies were produced in the last 10 years?

# %%
data.loc[(data['type'] == 'Movie') & (data['year'] > 2013)].shape[0]
# Out:
# 5159

# %% [markdown]
# From the above code we can conclude that 5159 Movies were produced in the last 10 years.

# %% [markdown]
# **Q10. which coutries produced the most movies?**

# %%
data.loc[data["type"] == "Movie","country"].value_counts()
# Out:
# United States                   1819
# India                            868
# United Kingdom                   164
# Canada                           104
# Egypt                             90
#                                 ...
# Spain, United Kingdom              1
# Canada, Norway                     1
# France, Senegal, Belgium           1
# Uruguay, Guatemala                 1
# United Arab Emirates, Jordan       1
# Name: country, Length: 594, dtype: int64

# %% [markdown]
# from the above analysis we can see that United states has produced the maximum number of Movies.

# %% [markdown]
# Q11. Waht is the most popular rating in TV shows?

# %%
data.loc[data["type"]=="TV Show","rating"].value_counts().reset_index
# Out:
# <bound method Series.reset_index of TV-MA    81
# TV-14    37
# TV-PG    15
# TV-Y7     6
# TV-Y      5
# TV-G      3
# Name: rating, dtype: int64>

# %% [markdown]
# form the above analysis we can see the most populer rationg is TV-14

# %% [markdown]
# Q11. show the title of the all TV that were released in India only.

# %%
data.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#   rating   duration                                         listed_in  \
# 7  TV-MA    125 min  Dramas, Independent Movies, International Movies
# 8  TV-14  9 Seasons                      British TV Shows, Reality TV
#
#                                          description     Date_N  year
# 7  On a photo shoot in Ghana, an American model s... 2021-09-24  2021
# ...

# %%
data[(data["type"]=="TV Show") & ( data["country"]=="India")]["title"]
# Out:
# 297                                  Navarasa
# 1293                            Pitta Kathalu
# 1520                          Paava Kadhaigal
# 3036             Jamtara - Sabka Number Ayega
# 4685                                    GHOUL
# 6024                                7 (Seven)
# 8172    Th Eena Meena Deeka Chase Comedy Show
# Name: title, dtype: object

# %% [markdown]
# Q12. Show Top directors, who gave the height number of TV shows & Movies to Netflix?

# %%
data["director"].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Don Michael Paul          10
# David Dhawan               9
# Name: director, dtype: int64

# %% [markdown]
# Q13. Show all the Records , where "category is Movies and Types is
# Comedies"or"Country is United Kingdom".
#
# Filtering (And or operators)

# %%
data.head()
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %%
data[(data["type"]=="Movie")& (data["type"]=="Comedies") |(data["country"]=="United Kingdom")]
# Out:
#      show_id     type                                title  \
# 8         s9  TV Show        The Great British Baking Show
# 292     s293    Movie                              Quartet
# 304     s305    Movie  Lady Boss: The Jackie Collins Story
# 402     s403    Movie      The Last Letter From Your Lover
# 589     s590    Movie                             Red Joan
# ...      ...      ...                                  ...
# 8697   s8698    Movie                      War on Everyone
# 8732   s8733    Movie                        White Chamber
# 8733   s8734    Movie                         White Island
# 8737   s8738    Movie           Why Are We Getting So Fat?
# 8786   s8787    Movie                         You Can Tutu
#
#                                     director  \
# 8                            Andy Devonshire
# 292                           Dustin Hoffman
# 304                            Laura Fairrie
# 402                       Augustine Frizzell
# ...

# %% [markdown]
# Q14 In how many Movies/shows, Tom cruis was cast?

# %%
data.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#   rating   duration                                         listed_in  \
# 7  TV-MA    125 min  Dramas, Independent Movies, International Movies
# 8  TV-14  9 Seasons                      British TV Shows, Reality TV
#
#                                          description     Date_N  year
# 7  On a photo shoot in Ghana, an American model s... 2021-09-24  2021
# ...

# %% [markdown]
# filtering

# %%
data[data["cast"]=="Tom Cruise"]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, rating, duration, listed_in, description, Date_N, year]
# Index: []

# %% [markdown]
# str.contains()

# %%
data[data["cast"].str.contains("Tom Cruise")]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added rating duration                   listed_in  \
# 341   August 1, 2021      R  189 min  Dramas, Independent Movies
# 1254   March 1, 2021      R  134 min      Classic Movies, Dramas
#
#                                             description     Date_N  year
# 341   Through chance, history and divine interventio... 2021-08-01  2021
# 1254  Motivated by money, a selfish workaholic seeki... 2021-03-01  2021

# %% [markdown]
# Creating the new data-frame

# %%
data_new=data.dropna()

# %%
data_new
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
data[data["cast"].str.contains("Tom Cruise")]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added rating duration                   listed_in  \
# 341   August 1, 2021      R  189 min  Dramas, Independent Movies
# 1254   March 1, 2021      R  134 min      Classic Movies, Dramas
#
#                                             description     Date_N  year
# 341   Through chance, history and divine interventio... 2021-08-01  2021
# 1254  Motivated by money, a selfish workaholic seeki... 2021-03-01  2021

# %% [markdown]
# Q15. What are diffrent Ratings defined by netflix?

# %% [markdown]
# nunique()

# %%
data.rating.nunique()
# Out:
# 14

# %% [markdown]
# unique()

# %%
data["rating"].unique()
# Out:
# array(['TV-MA', 'TV-14', 'PG-13', 'PG', 'R', 'TV-PG', 'G', 'TV-Y7',
#        'TV-G', 'TV-Y', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# Q15.1.How many Movies got the "TV-14" rating,In Canada?

# %%
data[(data["type"]=="Movie")& (data["rating"]=="TV-14")].shape
# Out:
# (1177, 13)

# %%
data[(data["type"]=="Movie")& (data["rating"]=="TV-14")& (data["country"]=="Canada")].shape
# Out:
# (10, 13)

# %% [markdown]
# **Q15.2 How many TV Show got the "TV-MA" rating, After year 2018?**

# %%
data.head()
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %%
data[(data["type"]=="TV Show")  & (data["rating"]=='TV-MA')]
# Out:
#      show_id     type                                 title  \
# 198     s199  TV Show  King of Boys: The Return of the King
# 273     s274  TV Show                         Gone for Good
# 276     s277  TV Show                               Valeria
# 297     s298  TV Show                              Navarasa
# 503     s504  TV Show                              The Mire
# ...      ...      ...                                   ...
# 7295   s7296  TV Show                      Leyla and Mecnun
# 7333   s7334  TV Show                            London Spy
# 8293   s8294  TV Show                              The Fear
# 8302   s8303  TV Show                              The Five
# 8599   s8600  TV Show                       Toast of London
#
#                                                director  \
# 198                                        Kemi Adetiba
# 273                                  Juan Carlos Medina
# 276                                       Inma Torrente
# ...

# %%
data[(data["type"]=="TV Show")  & (data["rating"]=='TV-MA') & (data["year"]>2018)]
# Out:
#      show_id     type                                 title  \
# 198     s199  TV Show  King of Boys: The Return of the King
# 273     s274  TV Show                         Gone for Good
# 276     s277  TV Show                               Valeria
# 297     s298  TV Show                              Navarasa
# 503     s504  TV Show                              The Mire
# ...      ...      ...                                   ...
# 3860   s3861  TV Show              Crime Diaries: Night Out
# 3928   s3929  TV Show                               Persona
# 4104   s4105  TV Show                               Hjørdis
# 4174   s4175  TV Show                              Innocent
# 6319   s6320  TV Show                        Bitter Daisies
#
#                                                director  \
# 198                                        Kemi Adetiba
# 273                                  Juan Carlos Medina
# 276                                       Inma Torrente
# ...

# %% [markdown]
# Q16. what is the maximum  duriation of a Movies/show on netflix ?

# %%
data["duration"].unique()
# Out:
# array(['125 min', '9 Seasons', '104 min', '127 min', '166 min', '103 min',
#        '97 min', '106 min', '96 min', '124 min', '116 min', '98 min',
#        '91 min', '115 min', '122 min', '99 min', '88 min', '100 min',
#        '102 min', '93 min', '95 min', '85 min', '83 min', '182 min',
#        '147 min', '90 min', '128 min', '143 min', '119 min', '114 min',
#        '118 min', '108 min', '117 min', '121 min', '142 min', '113 min',
#        '154 min', '120 min', '82 min', '94 min', '109 min', '101 min',
#        '105 min', '86 min', '229 min', '76 min', '89 min', '110 min',
#        '156 min', '112 min', '129 min', '107 min', '1 Season', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '145 min', '92 min',
#        '2 Seasons', '64 min', '59 min', '111 min', '87 min', '148 min',
#        '189 min', '141 min', '130 min', '7 Seasons', '68 min', '131 min',
#        '126 min', '155 min', '123 min', '84 min', '4 Seasons', '13 min',
# ...

# %%
data.duration.dtypes
# Out:
# dtype('O')

# %% [markdown]
# str.split()

# %%
data[["Minuts","Unit"]]=data["duration"].str.split(' ',expand=True)
# Out:
# <ipython-input-116-f8e5e1f07f7f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[["Minuts","Unit"]]=data["duration"].str.split(' ',expand=True)
# <ipython-input-116-f8e5e1f07f7f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[["Minuts","Unit"]]=data["duration"].str.split(' ',expand=True)

# %%
data.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#   rating   duration                                         listed_in  \
# 7  TV-MA    125 min  Dramas, Independent Movies, International Movies
# 8  TV-14  9 Seasons                      British TV Shows, Reality TV
#
#                                          description     Date_N  year Minuts  \
# 7  On a photo shoot in Ghana, an American model s... 2021-09-24  2021    125
# ...

# %% [markdown]
# max()

# %%
data["Minuts"].max()
# Out:
# '99'

# %%
data["Minuts"].min()
# Out:
# '1'

# %%
data.dtypes
# Out:
# show_id                object
# type                   object
# title                  object
# director               object
# cast                   object
# country                object
# date_added             object
# rating                 object
# duration               object
# listed_in              object
# description            object
# Date_N         datetime64[ns]
# year                    int64
# Minuts                 object
# Unit                   object
# dtype: object
